# %% [markdown]
# <a href="https://colab.research.google.com/github/mitshiabopm-bot/Bright-TV/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('/content/user_profile.csv.xlsx')
df
# Out:
#        UserID      Name    Surname                 Email  Gender  \
# 0          34     Chas     Biggers    Chas 351@yahoo.com    male
# 1          39  Wilburn      Crotty  Wilburn 303@mail.com    male
# 2          63  Emerson       Slane  Emerson 243@mail.com    male
# 3          90    Stacy      Sytsma    Stacy 273@mail.com    male
# 4          97    Lucas     Woolard    Lucas 233@mail.com    male
# ...       ...       ...        ...                   ...     ...
# 5370  1024878     Yong     Borelli    Yong 481@yahoo.com    male
# 5371   941625   Felipa   Mcculloch   Felipa 233@mail.com  female
# 5372  1645816     Kyle     Biggers   Kyle 64@abcmail.com    male
# 5373   925862     Bret    Tancredi  Bret 314@abcmail.com    male
# 5374  2384970    Hyman    Nicholls    Hyman 82@gmail.com    male
#
#               Race  Age       Province Social Media Handle
# 0            white   55     Free State            @Chas 35
# 1            black   54   Eastern Cape         @Wilburn 30
# ...

# %% [markdown]
# Finding nill values

# %%
df.isnull()
# Out:
#       UserID   Name  Surname  Email  Gender   Race    Age  Province  \
# 0      False  False    False  False   False  False  False     False
# 1      False  False    False  False   False  False  False     False
# 2      False  False    False  False   False  False  False     False
# 3      False  False    False  False   False  False  False     False
# 4      False  False    False  False   False  False  False     False
# ...      ...    ...      ...    ...     ...    ...    ...       ...
# 5370   False  False    False  False   False  False  False     False
# 5371   False  False    False  False   False   True  False     False
# 5372   False  False    False  False   False  False  False     False
# 5373   False  False    False  False   False  False  False     False
# 5374   False  False    False  False   False  False  False     False
#
#       Social Media Handle
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# ...

# %% [markdown]
# Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5375 entries, 0 to 5374
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   UserID               5375 non-null   int64
#  1   Name                 4455 non-null   object
#  2   Surname              4455 non-null   object
#  3   Email                5375 non-null   object
#  4   Gender               4673 non-null   object
#  5   Race                 4297 non-null   object
#  6   Age                  5375 non-null   int64
#  7   Province             4673 non-null   object
#  8   Social Media Handle  4455 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 378.1+ KB

# %% [markdown]
# Counting nill values

# %%
df.isnull().sum()
# Out:
# UserID                    0
# Name                    920
# Surname                 920
# Email                     0
# Gender                  702
# Race                   1078
# Age                       0
# Province                702
# Social Media Handle     920
# dtype: int64

# %% [markdown]
# Removing No values

# %%
df.dropna()
# Out:
#        UserID      Name   Surname                  Email Gender          Race  \
# 0          34     Chas    Biggers     Chas 351@yahoo.com   male         white
# 1          39  Wilburn     Crotty   Wilburn 303@mail.com   male         black
# 2          63  Emerson      Slane   Emerson 243@mail.com   male         black
# 3          90    Stacy     Sytsma     Stacy 273@mail.com   male      coloured
# 4          97    Lucas    Woolard     Lucas 233@mail.com   male      coloured
# ...       ...       ...       ...                    ...    ...           ...
# 5369   928622    Garry    Zweifel  Garry 285@mailxyz.com   male  indian_asian
# 5370  1024878     Yong    Borelli     Yong 481@yahoo.com   male         black
# 5372  1645816     Kyle    Biggers    Kyle 64@abcmail.com   male         white
# 5373   925862     Bret   Tancredi   Bret 314@abcmail.com   male  indian_asian
# 5374  2384970    Hyman   Nicholls     Hyman 82@gmail.com   male      coloured
#
# ...

# %% [markdown]
# Removing Duplicated

# %%
df.drop_duplicates()
# Out:
#        UserID      Name    Surname                 Email  Gender  \
# 0          34     Chas     Biggers    Chas 351@yahoo.com    male
# 1          39  Wilburn      Crotty  Wilburn 303@mail.com    male
# 2          63  Emerson       Slane  Emerson 243@mail.com    male
# 3          90    Stacy      Sytsma    Stacy 273@mail.com    male
# 4          97    Lucas     Woolard    Lucas 233@mail.com    male
# ...       ...       ...        ...                   ...     ...
# 5370  1024878     Yong     Borelli    Yong 481@yahoo.com    male
# 5371   941625   Felipa   Mcculloch   Felipa 233@mail.com  female
# 5372  1645816     Kyle     Biggers   Kyle 64@abcmail.com    male
# 5373   925862     Bret    Tancredi  Bret 314@abcmail.com    male
# 5374  2384970    Hyman    Nicholls    Hyman 82@gmail.com    male
#
#               Race  Age       Province Social Media Handle
# 0            white   55     Free State            @Chas 35
# 1            black   54   Eastern Cape         @Wilburn 30
# ...

# %% [markdown]
# Replacing No values by O

# %%
df.fillna(0)
# Out:
#        UserID      Name    Surname                 Email  Gender  \
# 0          34     Chas     Biggers    Chas 351@yahoo.com    male
# 1          39  Wilburn      Crotty  Wilburn 303@mail.com    male
# 2          63  Emerson       Slane  Emerson 243@mail.com    male
# 3          90    Stacy      Sytsma    Stacy 273@mail.com    male
# 4          97    Lucas     Woolard    Lucas 233@mail.com    male
# ...       ...       ...        ...                   ...     ...
# 5370  1024878     Yong     Borelli    Yong 481@yahoo.com    male
# 5371   941625   Felipa   Mcculloch   Felipa 233@mail.com  female
# 5372  1645816     Kyle     Biggers   Kyle 64@abcmail.com    male
# 5373   925862     Bret    Tancredi  Bret 314@abcmail.com    male
# 5374  2384970    Hyman    Nicholls    Hyman 82@gmail.com    male
#
#               Race  Age       Province Social Media Handle
# 0            white   55     Free State            @Chas 35
# 1            black   54   Eastern Cape         @Wilburn 30
# ...

# %%
df.groupby(["Name"]).size()
# Out:
# Name
# Abel        80
# Adela        9
# Alecia      13
# Alissa       6
# Anette      15
#             ..
# Wilton      71
# Winona      15
# Yolonda     14
# Yong        76
# Zetta        5
# Length: 100, dtype: int64

# %%
df.groupby(["Gender"]).size()
# Out:
# Gender
#            218
# female     537
# male      3918
# dtype: int64

# %%
df.groupby(["Race"]).size()
# Out:
# Race
#                  231
# black           1811
# coloured         679
# indian_asian     768
# other             48
# white            760
# dtype: int64

# %%
df.groupby(["Province"]).size()
# Out:
# Province
#                   218
# Eastern Cape      287
# Free State        156
# Gauteng          1704
# Kwazulu Natal     481
# Limpopo           368
# Mpumalanga        421
# North West        161
# Northern Cape      86
# Western Cape      791
# dtype: int64
